# %%
# Initialize Otter
import otter
grader = otter.Notebook("intro2Streamlit.ipynb")

# %% [markdown]
# ## Lecture Section

# %% [markdown]
# In this lecture, we will cover the basics of using Streamlit. Streamlit is an open-source Ptyhon framework that allows you to create interactive apps. You cann create an application with a Python notebook. Instead, you will copy all the code from this notebook into a .py file. When you publish your app, you'll take the link and submit that as the answer in the assignment section!
#
# We will cover:
# * Creating the App
# * Displaying Text
# * Getting User Input
# * Displaying Data with Pandas
# * Charts & Visualization
# * Layout
# * Session State
# * Cache
# * Upload & Download
# * Finishing Touches...
# * Deployment
#
# ChatGPT is very good at making basic Streamlit applications but striggles to add in more advanced interaction. I suggest starting with a prompt and fixing bugs/adding interactivity, after walking through this tutorial.

# %% [markdown]
# ### Creating the App

# %% [markdown]
# Create a .py file called `stream.py`. When you want to run your app, you will run `streamlit run stream.py`. Make sure to run `pip install streamlit` first! You can run your app at any point between sections and see what you've added - however, if you run it now, it will automatically update with your changes as you code.

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import time
import numpy as np

# %%
st.title("Hello, Streamlit!")
st.write("Welcome to your first Streamlit app.")
# Out:
# 2026-04-21 19:28:12.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Displaying Text

# %% [markdown]
# The next section of code gives you options for displaying text. The last one, `.write()`, is kind-of like Python's `print()` statement. It can display a lot of different things.

# %%
st.title("This is a Title")
st.header("This is a Header")
st.subheader("This is a Subheader")
st.text("Plain text goes here.")
st.markdown("**Bold**, *italic*, and `code` with Markdown!")
st.caption("Small caption text.")

st.write("st.write() can display almost anything!")
# Out:
# 2026-04-21 19:28:12.232 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Getting User Input

# %% [markdown]
# It is easy to get user-input. We can ask for text, show a slider, checkboxes, multi-select boxes, and provide buttons that do something special. To get the data back to us, we just assign the input back to a variable.

# %%
# Text input
name = st.text_input("What's your name?")
if name:
    st.write(f"Hello, {name}!")

# Slider
age = st.slider("Select your age", min_value=0, max_value=100, value=25)
st.write(f"You are {age} years old.")

# Checkbox
show_secret = st.checkbox("Show secret message")
if show_secret:
    st.success("You found the secret!")

# Select box
color = st.selectbox("Pick a color", ["Red", "Green", "Blue", "Yellow"])
st.write(f"You chose: {color}")

# Multi-select
fruits = st.multiselect("Pick your favorite fruits", ["Apple", "Banana", "Cherry", "Mango"])
st.write(f"Your favorites: {fruits}")

# Button
if st.button("Click me!"):
    st.balloons()  # Fun celebration effect!
# Out:
# 2026-04-21 19:28:12.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.345 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.348 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.388 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.389 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.397 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.401 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Displaying Data with Pandas

# %% [markdown]
# We can easily show tables in our app. We have two options: a static, non-interactive table and one that is dynamic. To create a static one, we call `.table()` and for the interactive one we call `.dataframe()`. We can use columns to provide some info about our data, too!

# %%
df = pd.DataFrame({
    "Name": ["Alice", "Bob", "Charlie", "Diana"],
    "Age": [28, 34, 22, 45],
    "Score": [88.5, 92.3, 78.1, 95.0]
})

st.subheader("Static Table")
st.table(df)  # Non-interactive

st.subheader("Interactive DataFrame")
st.dataframe(df, use_container_width=True)  # Sortable, scrollable

# Metric cards
col1, col2, col3 = st.columns(3)
col1.metric("Average Score", f"{df['Score'].mean():.1f}", "+2.3")
col2.metric("Total Students", len(df))
col3.metric("Top Score", f"{df['Score'].max()}")
# Out:
# 2026-04-21 19:28:12.432 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.436 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.440 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.441 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.443 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.444 Please replace `use_container_width` with `width`.
#
# `use_container_width` will be removed after 2025-12-31.
#
# For `use_container_width=True`, use `width='stretch'`. For `use_container_width=False`, use `width='content'`.
# 2026-04-21 19:28:12.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.446 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.457 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.459 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ### Charts & Visualization

# %% [markdown]
# Streamlit has built-in charts we can use, but we can use matplotlib, too. If we use matplotlib, the charts are not interactive or pretty. They're just an image.
#
# Notice that our data is made of random numebrs. Every time we click something on our app, the data changes because the entire file re-reruns, so we grab a new random sample. Keep this in mind if you are collecting user data or intentionally using random numbers.

# %%
data = pd.DataFrame(
    np.random.randn(50, 3),
    columns=["Series A", "Series B", "Series C"]
)

st.subheader("Built-in Charts")
st.line_chart(data)
st.bar_chart(data.abs().head(10))
st.area_chart(data)

# Matplotlib
st.subheader("Matplotlib Figure")
fig, ax = plt.subplots()
ax.hist(data["Series A"], bins=15, color="steelblue", edgecolor="white")
ax.set_title("Distribution of Series A")
ax.set_xlabel("Value")
ax.set_ylabel("Frequency")
st.pyplot(fig)
# Out:
# 2026-04-21 19:28:12.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.626 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.628 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.629 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.653 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.654 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.672 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.697 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ### Layout

# %% [markdown]
# There are a lot of layout options in Streamlit.
#
# First, we can create a sidebar. Right now, the sidebar does not do much of anything, but I gave you some ideas for what it *could* do.
#
# Second, we have columns! We already used these above, but I am repeating them here. In the columns, I gave some colored-block options: `info`, `success`, and `warning`. Notice that you can paste emojis and they will show on your application.
#
# Third are tabs. We can switch 'pages' with tabs if they are placed at the top and organized appropriately.
#
# Finally, we have an expander. Hidden content expands and shows when you click it!

# %%
# Sidebar
st.sidebar.title("⚙Settings")
theme = st.sidebar.radio("Choose theme", ["Light", "Dark"])
st.write(f"Current theme: **{theme}**")

# Columns
st.subheader("Columns")
col1, col2, col3 = st.columns(3)
with col1:
    st.info("Left")
with col2:
    st.success("Middle")
with col3:
    st.warning("Right")

# Tabs
st.subheader("Tabs")
tab1, tab2, tab3 = st.tabs(["Home", "Data", "ℹAbout"])
with tab1:
    st.write("Welcome to the Home tab!")
with tab2:
    st.write("Data goes here.")
with tab3:
    st.write("About this app.")

# Expander
with st.expander("Click to expand"):
    st.write("Hidden content revealed!")
# Out:
# 2026-04-21 19:28:12.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Session State

# %% [markdown]
# To understand session state, we can make a little `counter` application.`session_state` allows variables to persist when the application re-runs. Your counter should stay the same number when the random numbers aobve reset, for example.

# %%
if "count" not in st.session_state:
    st.session_state.count = 0

st.title("Counter App")
st.write(f"Current count: **{st.session_state.count}**")

col1, col2, col3 = st.columns(3)
with col1:
    if st.button("Increment"):
        st.session_state.count += 1
with col2:
    if st.button("Decrement"):
        st.session_state.count -= 1
with col3:
    if st.button("Reset"):
        st.session_state.count = 0
# Out:
# 2026-04-21 19:28:12.909 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.912 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.925 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.926 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.928 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.930 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.936 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Cache

# %% [markdown]
# Similarly, `@st.cache_data` prevents expensive functions from re-running on every user interaction.

# %%
@st.cache_data
def load_data():
    """Simulates a slow data loading operation."""
    time.sleep(2)  # Simulated delay
    return pd.DataFrame({
        "x": range(100),
        "y": [i ** 2 for i in range(100)]
    })

st.title("Caching Demo")
st.write("First load takes 2 seconds. Subsequent loads are instant!")

with st.spinner("Loading data..."):
    df = load_data()

st.success("Data loaded!")
st.line_chart(df.set_index("x"))
# Out:
# 2026-04-21 19:28:12.956 No runtime found, using MemoryCacheStorageManager
# 2026-04-21 19:28:12.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.964 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:12.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %% [markdown]
# ### Upload & Download

# %% [markdown]
# You can let users upload files and then analyze them, and users can download files, too! Upload a .csv file of your choice and watch it work.

# %%
st.title("File Upload & Download")

uploaded_file = st.file_uploader("Upload a CSV file", type=["csv"])

if uploaded_file is not None:
    df = pd.read_csv(uploaded_file)
    st.write(f"Loaded **{len(df)} rows** and **{len(df.columns)} columns**.")
    st.dataframe(df.head())

    # Download processed file
    csv = df.to_csv(index=False).encode("utf-8")
    st.download_button(
        label="Download processed CSV",
        data=csv,
        file_name="processed_data.csv",
        mime="text/csv"
    )
else:
    st.info("Please upload a CSV file to get started.")
# Out:
# 2026-04-21 19:28:13.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Finishing Touches

# %% [markdown]
# The last block of code are some finishing touches - you can explore what is down here, or delete it all and do something of your own!

# %%
st.set_page_config(page_title="Sales Dashboard", layout="wide")

# Sidebar controls
st.sidebar.title("Sales Dashboard")
num_months = st.sidebar.slider("Months to display", 1, 12, 6)
show_raw = st.sidebar.checkbox("I do NOTHING!")

@st.cache_data
def generate_sales_data(n):
    return pd.DataFrame({
        "Month": [f"Month {i+1}" for i in range(n)],
        "Revenue": np.random.randint(50000, 200000, n),
        "Expenses": np.random.randint(30000, 100000, n),
        "Customers": np.random.randint(100, 500, n)
    })

df = generate_sales_data(num_months)
df["Profit"] = df["Revenue"] - df["Expenses"]

# Title
st.title("Sales Dashboard")
st.markdown(f"Showing data for the last **{num_months} months**.")

# KPI Metrics
col1, col2, col3, col4 = st.columns(4)
col1.metric("Total Revenue", f"${df['Revenue'].sum():,}")
col2.metric("Total Expenses", f"${df['Expenses'].sum():,}")
col3.metric("Total Profit", f"${df['Profit'].sum():,}")
col4.metric("Total Customers", f"{df['Customers'].sum():,}")

st.divider()

# Charts in tabs
tab1, tab2 = st.tabs(["Revenue & Expenses", "Customers"])
with tab1:
    st.line_chart(df.set_index("Month")[["Revenue", "Expenses", "Profit"]])
with tab2:
    st.bar_chart(df.set_index("Month")["Customers"])
# Out:
# 2026-04-21 19:28:13.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.135 No runtime found, using MemoryCacheStorageManager
# 2026-04-21 19:28:13.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-21 19:28:13.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# ### Deployment

# %% [markdown]
# ---
# ## 11. Deploying Your App
#
# Deploy for free on **Streamlit Community Cloud**:
#
# 1. Push your code to a GitHub repository
# 2. Go to [share.streamlit.io](https://share.streamlit.io)
# 3. Connect your GitHub and select your repo
# 4. Click **Deploy!**
#
# Your app will be live at `https://your-app-name.streamlit.app`.
#
# ---
#
# ## Quick Reference Cheat Sheet
#
# | Function | Purpose |
# |---|---|
# | `st.title()`, `st.header()`, `st.subheader()` | Headings |
# | `st.write()`, `st.markdown()`, `st.text()` | Display text |
# | `st.text_input()`, `st.number_input()` | Text/number input |
# | `st.slider()`, `st.select_slider()` | Sliders |
# | `st.checkbox()`, `st.radio()`, `st.selectbox()` | Choice widgets |
# | `st.button()`, `st.download_button()` | Buttons |
# | `st.dataframe()`, `st.table()` | Data display |
# | `st.line_chart()`, `st.bar_chart()`, `st.area_chart()` | Built-in charts |
# | `st.pyplot()`, `st.plotly_chart()` | Custom charts |
# | `st.columns()`, `st.tabs()`, `st.sidebar` | Layout |
# | `st.expander()` | Collapsible section |
# | `st.session_state` | Persist state across reruns |
# | `@st.cache_data` | Cache expensive functions |
# | `st.spinner()`, `st.progress()` | Loading indicators |
# | `st.success()`, `st.error()`, `st.warning()`, `st.info()` | Alert boxes |
# | `st.file_uploader()` | File uploads |
# | `st.set_page_config()` | Page title, icon, layout |
#
# ---
# ## Further Resources
#
# - [Official Docs](https://docs.streamlit.io)
# - [Streamlit Gallery](https://streamlit.io/gallery) — Community app inspiration
# - [Streamlit Community Forum](https://discuss.streamlit.io)
# - [Cheat Sheet](https://docs.streamlit.io/library/cheatsheet)

# %% [markdown]
# ## Assignment Section

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **Question 1.** Replace 'url-here' with the url of your deployed application after completing the tutorial.

# %%
url = 'https://bisakh.stramlit.app'

# %% [markdown]
# <!-- END QUESTION -->
#
# **Question 2.**
#
# Please ignore me :) - I am a free point!

# %%
x = 1

# %%
grader.check("q2")
# Out:
# q2 results: All test cases passed!

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q2 results: All test cases passed!
